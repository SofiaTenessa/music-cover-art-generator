# %% [markdown]
# # Train Genre CNN on Colab
#
# Run this notebook on Google Colab with a free T4 GPU (`Runtime → Change runtime type → T4 GPU`).
#
# This is a backup in case local training on your Mac has issues.

# %%
# !pip install -q librosa soundfile torch torchaudio scikit-learn matplotlib seaborn tqdm

# %%
from google.colab import files
files.upload()  # upload kaggle.json
# !mkdir -p ~/.kaggle && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# !pip install -q kaggle
# !kaggle datasets download -d andradaolteanu/gtzan-dataset-music-genre-classification
# !unzip -q gtzan-dataset-music-genre-classification.zip -d gtzan

# %%
# !git clone https://github.com/<your-username>/music-cover-art-generator.git
# %cd music-cover-art-generator

# %%
import torch
print('CUDA:', torch.cuda.is_available())

# %%
# !python -m src.train --data-dir /content/gtzan/Data/genres_original --epochs 50 --run-name cnn_colab

# %%
# !python -m src.evaluate --ckpt models/cnn_colab_best.pt --data-dir /content/gtzan/Data/genres_original

# %%
from google.colab import files
files.download('models/cnn_colab_best.pt')
